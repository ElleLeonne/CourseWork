# %% [markdown]
# ## Jupyter Notebook Example

# %% [markdown]
# __Lily Erickson__

# %% [markdown]
# I am creating a machine learning chatbot, and need to learn how to manipulate data for this task.

# %%
print("Hello World (too cliche?)")
# Out:
# Hello World (too cliche?)

# %% [markdown]
# 1. <font color=pink>I</font>
# 2. <font color=blue>Like</font>
# 3. <font color=red>Numbered</font>
#     1. <font color=yellow>Lists</font>
#     2. <font color=pink>I</font>
#     3. <font color=green>Promise</font>
# ***
# ![alt text](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fi.ytimg.com%2Fvi%2FcJWojzF3wq8%2Fhqdefault.jpg&f=1&nofb=1 ":^)")
# ***
# * I
# * Had
# * To
